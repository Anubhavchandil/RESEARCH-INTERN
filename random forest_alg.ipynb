# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics._plot.confusion_matrix import plot_confusion_matrix

df= pd.read_excel('output_params_Phase.xlsx')

# # FCC=0, FCC+BCC=1, BCC=2

data= df.drop('Phase',axis='columns')
target= df['Phase']

from sklearn.model_selection import train_test_split

xtrain,xtest,ytrain,ytest= train_test_split(data,target,test_size=0.2,random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier


#Random Forest
from sklearn.model_selection import GridSearchCV
# Define the hyperparameter configuration space
rf_params = {
    'n_estimators': [100,150,200],
    'max_depth': [None,20,30,50],
    'min_samples_leaf': [1,2,4,8],
    "criterion":['gini','entropy']
}
clf = RandomForestClassifier(random_state=42)
grid = GridSearchCV(clf, rf_params, cv=3, scoring='accuracy',verbose=3)
grid.fit(xtrain,ytrain)
print(grid.best_params_)
print(grid.best_score_)
# Out:
# Fitting 3 folds for each of 96 candidates, totalling 288 fits
# [CV 1/3] END criterion=gini, max_depth=None, min_samples_leaf=1, n_estimators=100;, score=0.980 total time=   0.5s
# [CV 2/3] END criterion=gini, max_depth=None, min_samples_leaf=1, n_estimators=100;, score=0.984 total time=   0.5s
# [CV 3/3] END criterion=gini, max_depth=None, min_samples_leaf=1, n_estimators=100;, score=0.982 total time=   0.5s
# [CV 1/3] END criterion=gini, max_depth=None, min_samples_leaf=1, n_estimators=150;, score=0.980 total time=   0.9s
# [CV 2/3] END criterion=gini, max_depth=None, min_samples_leaf=1, n_estimators=150;, score=0.983 total time=   2.4s
# [CV 3/3] END criterion=gini, max_depth=None, min_samples_leaf=1, n_estimators=150;, score=0.982 total time=   2.3s
# [CV 1/3] END criterion=gini, max_depth=None, min_samples_leaf=1, n_estimators=200;, score=0.980 total time=   3.1s
# [CV 2/3] END criterion=gini, max_depth=None, min_samples_leaf=1, n_estimators=200;, score=0.984 total time=   3.2s
# [CV 3/3] END criterion=gini, max_depth=None, min_samples_leaf=1, n_estimators=200;, score=0.981 total time=   3.2s
# [CV 1/3] END criterion=gini, max_depth=None, min_samples_leaf=2, n_estimators=100;, score=0.980 total time=   1.5s
# [CV 2/3] END criterion=gini, max_depth=None, min_samples_leaf=2, n_estimators=100;, score=0.984 total time=   1.5s
# [CV 3/3] END criterion=gini, max_depth=None, min_samples_leaf=2, n_estimators=100;, score=0.980 total time=   1.5s
# [CV 1/3] END criterion=gini, max_depth=None, min_samples_leaf=2, n_estimators=150;, score=0.980 total time=   2.3s
# [CV 2/3] END criterion=gini, max_depth=None, min_samples_leaf=2, n_estimators=150;, score=0.984 total time=   2.3s
# [CV 3/3] END criterion=gini, max_depth=None, min_samples_leaf=2, n_estimators=150;, score=0.981 total time=   2.4s
# [CV 1/3] END criterion=gini, max_depth=None, min_samples_leaf=2, n_estimators=200;, score=0.981 total time=   2.9s
# [CV 2/3] END criterion=gini, max_depth=None, min_samples_leaf=2, n_estimators=200;, score=0.983 total time=   3.2s
# [CV 3/3] END criterion=gini, max_depth=None, min_samples_leaf=2, n_estimators=200;, score=0.982 total time=   3.1s
# [CV 1/3] END criterion=gini, max_depth=None, min_samples_leaf=4, n_estimators=100;, score=0.980 total time=   1.4s
# [CV 2/3] END criterion=gini, max_depth=None, min_samples_leaf=4, n_estimators=100;, score=0.979 total time=   1.5s
# [CV 3/3] END criterion=gini, max_depth=None, min_samples_leaf=4, n_estimators=100;, score=0.978 total time=   1.4s
# [CV 1/3] END criterion=gini, max_depth=None, min_samples_leaf=4, n_estimators=150;, score=0.979 total time=   2.2s
# [CV 2/3] END criterion=gini, max_depth=None, min_samples_leaf=4, n_estimators=150;, score=0.980 total time=   2.3s
# [CV 3/3] END criterion=gini, max_depth=None, min_samples_leaf=4, n_estimators=150;, score=0.979 total time=   2.3s
# [CV 1/3] END criterion=gini, max_depth=None, min_samples_leaf=4, n_estimators=200;, score=0.979 total time=   3.0s
# [CV 2/3] END criterion=gini, max_depth=None, min_samples_leaf=4, n_estimators=200;, score=0.980 total time=   2.9s
# [CV 3/3] END criterion=gini, max_depth=None, min_samples_leaf=4, n_estimators=200;, score=0.979 total time=   3.0s
# [CV 1/3] END criterion=gini, max_depth=None, min_samples_leaf=8, n_estimators=100;, score=0.977 total time=   1.4s
# [CV 2/3] END criterion=gini, max_depth=None, min_samples_leaf=8, n_estimators=100;, score=0.978 total time=   1.4s
# [CV 3/3] END criterion=gini, max_depth=None, min_samples_leaf=8, n_estimators=100;, score=0.977 total time=   1.4s
# [CV 1/3] END criterion=gini, max_depth=None, min_samples_leaf=8, n_estimators=150;, score=0.978 total time=   2.1s
# [CV 2/3] END criterion=gini, max_depth=None, min_samples_leaf=8, n_estimators=150;, score=0.977 total time=   2.2s
# [CV 3/3] END criterion=gini, max_depth=None, min_samples_leaf=8, n_estimators=150;, score=0.978 total time=   2.1s
# [CV 1/3] END criterion=gini, max_depth=None, min_samples_leaf=8, n_estimators=200;, score=0.977 total time=   2.8s
# [CV 2/3] END criterion=gini, max_depth=None, min_samples_leaf=8, n_estimators=200;, score=0.977 total time=   3.0s
# [CV 3/3] END criterion=gini, max_depth=None, min_samples_leaf=8, n_estimators=200;, score=0.977 total time=   2.9s
# [CV 1/3] END criterion=gini, max_depth=20, min_samples_leaf=1, n_estimators=100;, score=0.980 total time=   1.5s
# [CV 2/3] END criterion=gini, max_depth=20, min_samples_leaf=1, n_estimators=100;, score=0.984 total time=   1.5s
# [CV 3/3] END criterion=gini, max_depth=20, min_samples_leaf=1, n_estimators=100;, score=0.982 total time=   1.6s
# [CV 1/3] END criterion=gini, max_depth=20, min_samples_leaf=1, n_estimators=150;, score=0.980 total time=   2.3s
# [CV 2/3] END criterion=gini, max_depth=20, min_samples_leaf=1, n_estimators=150;, score=0.983 total time=   2.3s
# [CV 3/3] END criterion=gini, max_depth=20, min_samples_leaf=1, n_estimators=150;, score=0.982 total time=   2.3s
# [CV 1/3] END criterion=gini, max_depth=20, min_samples_leaf=1, n_estimators=200;, score=0.980 total time=   3.2s
# [CV 2/3] END criterion=gini, max_depth=20, min_samples_leaf=1, n_estimators=200;, score=0.984 total time=   3.1s
# [CV 3/3] END criterion=gini, max_depth=20, min_samples_leaf=1, n_estimators=200;, score=0.982 total time=   3.1s
# [CV 1/3] END criterion=gini, max_depth=20, min_samples_leaf=2, n_estimators=100;, score=0.981 total time=   1.4s
# [CV 2/3] END criterion=gini, max_depth=20, min_samples_leaf=2, n_estimators=100;, score=0.984 total time=   1.5s
# [CV 3/3] END criterion=gini, max_depth=20, min_samples_leaf=2, n_estimators=100;, score=0.980 total time=   1.5s
# [CV 1/3] END criterion=gini, max_depth=20, min_samples_leaf=2, n_estimators=150;, score=0.980 total time=   2.3s
# [CV 2/3] END criterion=gini, max_depth=20, min_samples_leaf=2, n_estimators=150;, score=0.984 total time=   2.3s
# [CV 3/3] END criterion=gini, max_depth=20, min_samples_leaf=2, n_estimators=150;, score=0.981 total time=   2.2s
# [CV 1/3] END criterion=gini, max_depth=20, min_samples_leaf=2, n_estimators=200;, score=0.981 total time=   3.0s
# [CV 2/3] END criterion=gini, max_depth=20, min_samples_leaf=2, n_estimators=200;, score=0.982 total time=   3.1s
# [CV 3/3] END criterion=gini, max_depth=20, min_samples_leaf=2, n_estimators=200;, score=0.982 total time=   3.1s
# [CV 1/3] END criterion=gini, max_depth=20, min_samples_leaf=4, n_estimators=100;, score=0.980 total time=   1.5s
# [CV 2/3] END criterion=gini, max_depth=20, min_samples_leaf=4, n_estimators=100;, score=0.980 total time=   1.5s
# [CV 3/3] END criterion=gini, max_depth=20, min_samples_leaf=4, n_estimators=100;, score=0.978 total time=   1.4s
# [CV 1/3] END criterion=gini, max_depth=20, min_samples_leaf=4, n_estimators=150;, score=0.979 total time=   2.2s
# [CV 2/3] END criterion=gini, max_depth=20, min_samples_leaf=4, n_estimators=150;, score=0.979 total time=   2.1s
# [CV 3/3] END criterion=gini, max_depth=20, min_samples_leaf=4, n_estimators=150;, score=0.979 total time=   2.2s
# [CV 1/3] END criterion=gini, max_depth=20, min_samples_leaf=4, n_estimators=200;, score=0.979 total time=   3.0s
# [CV 2/3] END criterion=gini, max_depth=20, min_samples_leaf=4, n_estimators=200;, score=0.980 total time=   3.0s
# [CV 3/3] END criterion=gini, max_depth=20, min_samples_leaf=4, n_estimators=200;, score=0.979 total time=   2.9s
# [CV 1/3] END criterion=gini, max_depth=20, min_samples_leaf=8, n_estimators=100;, score=0.977 total time=   1.5s
# [CV 2/3] END criterion=gini, max_depth=20, min_samples_leaf=8, n_estimators=100;, score=0.978 total time=   1.4s
# [CV 3/3] END criterion=gini, max_depth=20, min_samples_leaf=8, n_estimators=100;, score=0.977 total time=   1.4s
# [CV 1/3] END criterion=gini, max_depth=20, min_samples_leaf=8, n_estimators=150;, score=0.978 total time=   2.3s
# [CV 2/3] END criterion=gini, max_depth=20, min_samples_leaf=8, n_estimators=150;, score=0.977 total time=   2.1s
# [CV 3/3] END criterion=gini, max_depth=20, min_samples_leaf=8, n_estimators=150;, score=0.978 total time=   2.2s
# [CV 1/3] END criterion=gini, max_depth=20, min_samples_leaf=8, n_estimators=200;, score=0.977 total time=   2.9s
# [CV 2/3] END criterion=gini, max_depth=20, min_samples_leaf=8, n_estimators=200;, score=0.977 total time=   2.8s
# [CV 3/3] END criterion=gini, max_depth=20, min_samples_leaf=8, n_estimators=200;, score=0.977 total time=   3.0s
# [CV 1/3] END criterion=gini, max_depth=30, min_samples_leaf=1, n_estimators=100;, score=0.980 total time=   1.6s
# [CV 2/3] END criterion=gini, max_depth=30, min_samples_leaf=1, n_estimators=100;, score=0.984 total time=   1.5s
# [CV 3/3] END criterion=gini, max_depth=30, min_samples_leaf=1, n_estimators=100;, score=0.982 total time=   1.6s
# [CV 1/3] END criterion=gini, max_depth=30, min_samples_leaf=1, n_estimators=150;, score=0.980 total time=   2.3s
# [CV 2/3] END criterion=gini, max_depth=30, min_samples_leaf=1, n_estimators=150;, score=0.983 total time=   2.4s
# [CV 3/3] END criterion=gini, max_depth=30, min_samples_leaf=1, n_estimators=150;, score=0.982 total time=   2.3s
# [CV 1/3] END criterion=gini, max_depth=30, min_samples_leaf=1, n_estimators=200;, score=0.980 total time=   3.2s
# [CV 2/3] END criterion=gini, max_depth=30, min_samples_leaf=1, n_estimators=200;, score=0.984 total time=   2.9s
# [CV 3/3] END criterion=gini, max_depth=30, min_samples_leaf=1, n_estimators=200;, score=0.981 total time=   3.2s
# [CV 1/3] END criterion=gini, max_depth=30, min_samples_leaf=2, n_estimators=100;, score=0.980 total time=   1.5s
# [CV 2/3] END criterion=gini, max_depth=30, min_samples_leaf=2, n_estimators=100;, score=0.984 total time=   1.5s
# [CV 3/3] END criterion=gini, max_depth=30, min_samples_leaf=2, n_estimators=100;, score=0.980 total time=   1.5s
# [CV 1/3] END criterion=gini, max_depth=30, min_samples_leaf=2, n_estimators=150;, score=0.980 total time=   2.2s
# [CV 2/3] END criterion=gini, max_depth=30, min_samples_leaf=2, n_estimators=150;, score=0.984 total time=   2.2s
# [CV 3/3] END criterion=gini, max_depth=30, min_samples_leaf=2, n_estimators=150;, score=0.981 total time=   2.3s
# [CV 1/3] END criterion=gini, max_depth=30, min_samples_leaf=2, n_estimators=200;, score=0.981 total time=   3.1s
# [CV 2/3] END criterion=gini, max_depth=30, min_samples_leaf=2, n_estimators=200;, score=0.983 total time=   3.2s
# [CV 3/3] END criterion=gini, max_depth=30, min_samples_leaf=2, n_estimators=200;, score=0.982 total time=   3.1s
# [CV 1/3] END criterion=gini, max_depth=30, min_samples_leaf=4, n_estimators=100;, score=0.980 total time=   1.5s
# [CV 2/3] END criterion=gini, max_depth=30, min_samples_leaf=4, n_estimators=100;, score=0.979 total time=   1.5s
# [CV 3/3] END criterion=gini, max_depth=30, min_samples_leaf=4, n_estimators=100;, score=0.978 total time=   1.5s
# [CV 1/3] END criterion=gini, max_depth=30, min_samples_leaf=4, n_estimators=150;, score=0.979 total time=   2.3s
# [CV 2/3] END criterion=gini, max_depth=30, min_samples_leaf=4, n_estimators=150;, score=0.980 total time=   2.2s
# [CV 3/3] END criterion=gini, max_depth=30, min_samples_leaf=4, n_estimators=150;, score=0.979 total time=   2.3s
# [CV 1/3] END criterion=gini, max_depth=30, min_samples_leaf=4, n_estimators=200;, score=0.979 total time=   3.1s
# [CV 2/3] END criterion=gini, max_depth=30, min_samples_leaf=4, n_estimators=200;, score=0.980 total time=   3.0s
# [CV 3/3] END criterion=gini, max_depth=30, min_samples_leaf=4, n_estimators=200;, score=0.979 total time=   3.0s
# [CV 1/3] END criterion=gini, max_depth=30, min_samples_leaf=8, n_estimators=100;, score=0.977 total time=   1.5s
# [CV 2/3] END criterion=gini, max_depth=30, min_samples_leaf=8, n_estimators=100;, score=0.978 total time=   1.4s
# [CV 3/3] END criterion=gini, max_depth=30, min_samples_leaf=8, n_estimators=100;, score=0.977 total time=   1.4s
# [CV 1/3] END criterion=gini, max_depth=30, min_samples_leaf=8, n_estimators=150;, score=0.978 total time=   2.2s
# [CV 2/3] END criterion=gini, max_depth=30, min_samples_leaf=8, n_estimators=150;, score=0.977 total time=   2.1s
# [CV 3/3] END criterion=gini, max_depth=30, min_samples_leaf=8, n_estimators=150;, score=0.978 total time=   2.2s
# [CV 1/3] END criterion=gini, max_depth=30, min_samples_leaf=8, n_estimators=200;, score=0.977 total time=   2.9s
# [CV 2/3] END criterion=gini, max_depth=30, min_samples_leaf=8, n_estimators=200;, score=0.977 total time=   2.8s
# [CV 3/3] END criterion=gini, max_depth=30, min_samples_leaf=8, n_estimators=200;, score=0.977 total time=   2.9s
# [CV 1/3] END criterion=gini, max_depth=50, min_samples_leaf=1, n_estimators=100;, score=0.980 total time=   1.6s
# [CV 2/3] END criterion=gini, max_depth=50, min_samples_leaf=1, n_estimators=100;, score=0.984 total time=   1.4s
# [CV 3/3] END criterion=gini, max_depth=50, min_samples_leaf=1, n_estimators=100;, score=0.982 total time=   1.4s
# [CV 1/3] END criterion=gini, max_depth=50, min_samples_leaf=1, n_estimators=150;, score=0.980 total time=   2.2s
# [CV 2/3] END criterion=gini, max_depth=50, min_samples_leaf=1, n_estimators=150;, score=0.983 total time=   2.2s
# [CV 3/3] END criterion=gini, max_depth=50, min_samples_leaf=1, n_estimators=150;, score=0.982 total time=   2.2s
# [CV 1/3] END criterion=gini, max_depth=50, min_samples_leaf=1, n_estimators=200;, score=0.980 total time=   3.0s
# [CV 2/3] END criterion=gini, max_depth=50, min_samples_leaf=1, n_estimators=200;, score=0.984 total time=   3.1s
# [CV 3/3] END criterion=gini, max_depth=50, min_samples_leaf=1, n_estimators=200;, score=0.981 total time=   3.2s
# [CV 1/3] END criterion=gini, max_depth=50, min_samples_leaf=2, n_estimators=100;, score=0.980 total time=   1.4s
# [CV 2/3] END criterion=gini, max_depth=50, min_samples_leaf=2, n_estimators=100;, score=0.984 total time=   1.5s
# [CV 3/3] END criterion=gini, max_depth=50, min_samples_leaf=2, n_estimators=100;, score=0.980 total time=   1.6s
# [CV 1/3] END criterion=gini, max_depth=50, min_samples_leaf=2, n_estimators=150;, score=0.980 total time=   2.2s
# [CV 2/3] END criterion=gini, max_depth=50, min_samples_leaf=2, n_estimators=150;, score=0.984 total time=   2.3s
# [CV 3/3] END criterion=gini, max_depth=50, min_samples_leaf=2, n_estimators=150;, score=0.981 total time=   2.4s
# [CV 1/3] END criterion=gini, max_depth=50, min_samples_leaf=2, n_estimators=200;, score=0.981 total time=   3.1s
# [CV 2/3] END criterion=gini, max_depth=50, min_samples_leaf=2, n_estimators=200;, score=0.983 total time=   3.2s
# [CV 3/3] END criterion=gini, max_depth=50, min_samples_leaf=2, n_estimators=200;, score=0.982 total time=   3.0s
# [CV 1/3] END criterion=gini, max_depth=50, min_samples_leaf=4, n_estimators=100;, score=0.980 total time=   1.5s
# [CV 2/3] END criterion=gini, max_depth=50, min_samples_leaf=4, n_estimators=100;, score=0.979 total time=   1.5s
# [CV 3/3] END criterion=gini, max_depth=50, min_samples_leaf=4, n_estimators=100;, score=0.978 total time=   1.4s
# [CV 1/3] END criterion=gini, max_depth=50, min_samples_leaf=4, n_estimators=150;, score=0.979 total time=   2.2s
# [CV 2/3] END criterion=gini, max_depth=50, min_samples_leaf=4, n_estimators=150;, score=0.980 total time=   2.3s
# [CV 3/3] END criterion=gini, max_depth=50, min_samples_leaf=4, n_estimators=150;, score=0.979 total time=   2.2s
# [CV 1/3] END criterion=gini, max_depth=50, min_samples_leaf=4, n_estimators=200;, score=0.979 total time=   3.0s
# [CV 2/3] END criterion=gini, max_depth=50, min_samples_leaf=4, n_estimators=200;, score=0.980 total time=   3.0s
# [CV 3/3] END criterion=gini, max_depth=50, min_samples_leaf=4, n_estimators=200;, score=0.979 total time=   2.9s
# [CV 1/3] END criterion=gini, max_depth=50, min_samples_leaf=8, n_estimators=100;, score=0.977 total time=   1.4s
# [CV 2/3] END criterion=gini, max_depth=50, min_samples_leaf=8, n_estimators=100;, score=0.978 total time=   1.4s
# [CV 3/3] END criterion=gini, max_depth=50, min_samples_leaf=8, n_estimators=100;, score=0.977 total time=   1.4s
# [CV 1/3] END criterion=gini, max_depth=50, min_samples_leaf=8, n_estimators=150;, score=0.978 total time=   2.1s
# [CV 2/3] END criterion=gini, max_depth=50, min_samples_leaf=8, n_estimators=150;, score=0.977 total time=   2.1s
# [CV 3/3] END criterion=gini, max_depth=50, min_samples_leaf=8, n_estimators=150;, score=0.978 total time=   2.1s
# [CV 1/3] END criterion=gini, max_depth=50, min_samples_leaf=8, n_estimators=200;, score=0.977 total time=   2.9s
# [CV 2/3] END criterion=gini, max_depth=50, min_samples_leaf=8, n_estimators=200;, score=0.977 total time=   2.9s
# [CV 3/3] END criterion=gini, max_depth=50, min_samples_leaf=8, n_estimators=200;, score=0.977 total time=   2.8s
# [CV 1/3] END criterion=entropy, max_depth=None, min_samples_leaf=1, n_estimators=100;, score=0.982 total time=   1.8s
# [CV 2/3] END criterion=entropy, max_depth=None, min_samples_leaf=1, n_estimators=100;, score=0.984 total time=   1.9s
# [CV 3/3] END criterion=entropy, max_depth=None, min_samples_leaf=1, n_estimators=100;, score=0.982 total time=   1.9s
# [CV 1/3] END criterion=entropy, max_depth=None, min_samples_leaf=1, n_estimators=150;, score=0.981 total time=   2.9s
# [CV 2/3] END criterion=entropy, max_depth=None, min_samples_leaf=1, n_estimators=150;, score=0.984 total time=   2.9s
# [CV 3/3] END criterion=entropy, max_depth=None, min_samples_leaf=1, n_estimators=150;, score=0.982 total time=   2.9s
# [CV 1/3] END criterion=entropy, max_depth=None, min_samples_leaf=1, n_estimators=200;, score=0.982 total time=   3.8s
# [CV 2/3] END criterion=entropy, max_depth=None, min_samples_leaf=1, n_estimators=200;, score=0.984 total time=   3.8s
# [CV 3/3] END criterion=entropy, max_depth=None, min_samples_leaf=1, n_estimators=200;, score=0.983 total time=   3.7s
# [CV 1/3] END criterion=entropy, max_depth=None, min_samples_leaf=2, n_estimators=100;, score=0.980 total time=   1.9s
# [CV 2/3] END criterion=entropy, max_depth=None, min_samples_leaf=2, n_estimators=100;, score=0.983 total time=   1.8s
# [CV 3/3] END criterion=entropy, max_depth=None, min_samples_leaf=2, n_estimators=100;, score=0.982 total time=   1.9s
# [CV 1/3] END criterion=entropy, max_depth=None, min_samples_leaf=2, n_estimators=150;, score=0.981 total time=   2.7s
# [CV 2/3] END criterion=entropy, max_depth=None, min_samples_leaf=2, n_estimators=150;, score=0.984 total time=   2.8s
# [CV 3/3] END criterion=entropy, max_depth=None, min_samples_leaf=2, n_estimators=150;, score=0.983 total time=   2.8s
# [CV 1/3] END criterion=entropy, max_depth=None, min_samples_leaf=2, n_estimators=200;, score=0.981 total time=   3.9s
# [CV 2/3] END criterion=entropy, max_depth=None, min_samples_leaf=2, n_estimators=200;, score=0.983 total time=   3.6s
# [CV 3/3] END criterion=entropy, max_depth=None, min_samples_leaf=2, n_estimators=200;, score=0.983 total time=   3.8s
# [CV 1/3] END criterion=entropy, max_depth=None, min_samples_leaf=4, n_estimators=100;, score=0.980 total time=   1.8s
# [CV 2/3] END criterion=entropy, max_depth=None, min_samples_leaf=4, n_estimators=100;, score=0.982 total time=   1.8s
# [CV 3/3] END criterion=entropy, max_depth=None, min_samples_leaf=4, n_estimators=100;, score=0.982 total time=   1.9s
# [CV 1/3] END criterion=entropy, max_depth=None, min_samples_leaf=4, n_estimators=150;, score=0.980 total time=   2.9s
# [CV 2/3] END criterion=entropy, max_depth=None, min_samples_leaf=4, n_estimators=150;, score=0.983 total time=   2.7s
# [CV 3/3] END criterion=entropy, max_depth=None, min_samples_leaf=4, n_estimators=150;, score=0.982 total time=   2.8s
# [CV 1/3] END criterion=entropy, max_depth=None, min_samples_leaf=4, n_estimators=200;, score=0.981 total time=   3.7s
# [CV 2/3] END criterion=entropy, max_depth=None, min_samples_leaf=4, n_estimators=200;, score=0.983 total time=   3.8s
# [CV 3/3] END criterion=entropy, max_depth=None, min_samples_leaf=4, n_estimators=200;, score=0.982 total time=   3.7s
# [CV 1/3] END criterion=entropy, max_depth=None, min_samples_leaf=8, n_estimators=100;, score=0.978 total time=   1.8s
# [CV 2/3] END criterion=entropy, max_depth=None, min_samples_leaf=8, n_estimators=100;, score=0.978 total time=   1.8s
# [CV 3/3] END criterion=entropy, max_depth=None, min_samples_leaf=8, n_estimators=100;, score=0.981 total time=   1.8s
# [CV 1/3] END criterion=entropy, max_depth=None, min_samples_leaf=8, n_estimators=150;, score=0.979 total time=   2.8s
# [CV 2/3] END criterion=entropy, max_depth=None, min_samples_leaf=8, n_estimators=150;, score=0.979 total time=   2.7s
# [CV 3/3] END criterion=entropy, max_depth=None, min_samples_leaf=8, n_estimators=150;, score=0.982 total time=   2.7s
# [CV 1/3] END criterion=entropy, max_depth=None, min_samples_leaf=8, n_estimators=200;, score=0.978 total time=   3.7s
# [CV 2/3] END criterion=entropy, max_depth=None, min_samples_leaf=8, n_estimators=200;, score=0.979 total time=   3.5s
# [CV 3/3] END criterion=entropy, max_depth=None, min_samples_leaf=8, n_estimators=200;, score=0.980 total time=   3.6s
# [CV 1/3] END criterion=entropy, max_depth=20, min_samples_leaf=1, n_estimators=100;, score=0.982 total time=   1.9s
# [CV 2/3] END criterion=entropy, max_depth=20, min_samples_leaf=1, n_estimators=100;, score=0.985 total time=   1.9s
# [CV 3/3] END criterion=entropy, max_depth=20, min_samples_leaf=1, n_estimators=100;, score=0.982 total time=   1.8s
# [CV 1/3] END criterion=entropy, max_depth=20, min_samples_leaf=1, n_estimators=150;, score=0.981 total time=   2.9s
# [CV 2/3] END criterion=entropy, max_depth=20, min_samples_leaf=1, n_estimators=150;, score=0.985 total time=   3.0s
# [CV 3/3] END criterion=entropy, max_depth=20, min_samples_leaf=1, n_estimators=150;, score=0.982 total time=   2.8s
# [CV 1/3] END criterion=entropy, max_depth=20, min_samples_leaf=1, n_estimators=200;, score=0.982 total time=   4.0s
# [CV 2/3] END criterion=entropy, max_depth=20, min_samples_leaf=1, n_estimators=200;, score=0.984 total time=   3.8s
# [CV 3/3] END criterion=entropy, max_depth=20, min_samples_leaf=1, n_estimators=200;, score=0.983 total time=   3.7s
# [CV 1/3] END criterion=entropy, max_depth=20, min_samples_leaf=2, n_estimators=100;, score=0.980 total time=   2.0s
# [CV 2/3] END criterion=entropy, max_depth=20, min_samples_leaf=2, n_estimators=100;, score=0.983 total time=   1.8s
# [CV 3/3] END criterion=entropy, max_depth=20, min_samples_leaf=2, n_estimators=100;, score=0.982 total time=   1.8s
# [CV 1/3] END criterion=entropy, max_depth=20, min_samples_leaf=2, n_estimators=150;, score=0.981 total time=   2.9s
# [CV 2/3] END criterion=entropy, max_depth=20, min_samples_leaf=2, n_estimators=150;, score=0.984 total time=   2.8s
# [CV 3/3] END criterion=entropy, max_depth=20, min_samples_leaf=2, n_estimators=150;, score=0.983 total time=   2.8s
# [CV 1/3] END criterion=entropy, max_depth=20, min_samples_leaf=2, n_estimators=200;, score=0.981 total time=   4.0s
# [CV 2/3] END criterion=entropy, max_depth=20, min_samples_leaf=2, n_estimators=200;, score=0.983 total time=   3.8s
# [CV 3/3] END criterion=entropy, max_depth=20, min_samples_leaf=2, n_estimators=200;, score=0.983 total time=   3.8s
# [CV 1/3] END criterion=entropy, max_depth=20, min_samples_leaf=4, n_estimators=100;, score=0.980 total time=   1.9s
# [CV 2/3] END criterion=entropy, max_depth=20, min_samples_leaf=4, n_estimators=100;, score=0.982 total time=   1.8s
# [CV 3/3] END criterion=entropy, max_depth=20, min_samples_leaf=4, n_estimators=100;, score=0.982 total time=   1.9s
# [CV 1/3] END criterion=entropy, max_depth=20, min_samples_leaf=4, n_estimators=150;, score=0.981 total time=   2.9s
# [CV 2/3] END criterion=entropy, max_depth=20, min_samples_leaf=4, n_estimators=150;, score=0.983 total time=   2.9s
# [CV 3/3] END criterion=entropy, max_depth=20, min_samples_leaf=4, n_estimators=150;, score=0.982 total time=   2.4s
# [CV 1/3] END criterion=entropy, max_depth=20, min_samples_leaf=4, n_estimators=200;, score=0.981 total time=   3.7s
# [CV 2/3] END criterion=entropy, max_depth=20, min_samples_leaf=4, n_estimators=200;, score=0.983 total time=   3.8s
# [CV 3/3] END criterion=entropy, max_depth=20, min_samples_leaf=4, n_estimators=200;, score=0.982 total time=   3.7s
# [CV 1/3] END criterion=entropy, max_depth=20, min_samples_leaf=8, n_estimators=100;, score=0.978 total time=   1.8s
# [CV 2/3] END criterion=entropy, max_depth=20, min_samples_leaf=8, n_estimators=100;, score=0.978 total time=   1.8s
# [CV 3/3] END criterion=entropy, max_depth=20, min_samples_leaf=8, n_estimators=100;, score=0.981 total time=   1.7s
# [CV 1/3] END criterion=entropy, max_depth=20, min_samples_leaf=8, n_estimators=150;, score=0.979 total time=   2.6s
# [CV 2/3] END criterion=entropy, max_depth=20, min_samples_leaf=8, n_estimators=150;, score=0.979 total time=   2.9s
# [CV 3/3] END criterion=entropy, max_depth=20, min_samples_leaf=8, n_estimators=150;, score=0.982 total time=   2.9s
# [CV 1/3] END criterion=entropy, max_depth=20, min_samples_leaf=8, n_estimators=200;, score=0.978 total time=   3.6s
# [CV 2/3] END criterion=entropy, max_depth=20, min_samples_leaf=8, n_estimators=200;, score=0.979 total time=   3.6s
# [CV 3/3] END criterion=entropy, max_depth=20, min_samples_leaf=8, n_estimators=200;, score=0.980 total time=   3.6s
# [CV 1/3] END criterion=entropy, max_depth=30, min_samples_leaf=1, n_estimators=100;, score=0.982 total time=   1.9s
# [CV 2/3] END criterion=entropy, max_depth=30, min_samples_leaf=1, n_estimators=100;, score=0.984 total time=   1.9s
# [CV 3/3] END criterion=entropy, max_depth=30, min_samples_leaf=1, n_estimators=100;, score=0.982 total time=   1.8s
# [CV 1/3] END criterion=entropy, max_depth=30, min_samples_leaf=1, n_estimators=150;, score=0.981 total time=   2.8s
# [CV 2/3] END criterion=entropy, max_depth=30, min_samples_leaf=1, n_estimators=150;, score=0.984 total time=   2.9s
# [CV 3/3] END criterion=entropy, max_depth=30, min_samples_leaf=1, n_estimators=150;, score=0.982 total time=   2.8s
# [CV 1/3] END criterion=entropy, max_depth=30, min_samples_leaf=1, n_estimators=200;, score=0.982 total time=   3.8s
# [CV 2/3] END criterion=entropy, max_depth=30, min_samples_leaf=1, n_estimators=200;, score=0.984 total time=   3.7s
# [CV 3/3] END criterion=entropy, max_depth=30, min_samples_leaf=1, n_estimators=200;, score=0.983 total time=   4.0s
# [CV 1/3] END criterion=entropy, max_depth=30, min_samples_leaf=2, n_estimators=100;, score=0.980 total time=   1.9s
# [CV 2/3] END criterion=entropy, max_depth=30, min_samples_leaf=2, n_estimators=100;, score=0.983 total time=   1.9s
# [CV 3/3] END criterion=entropy, max_depth=30, min_samples_leaf=2, n_estimators=100;, score=0.982 total time=   1.9s
# [CV 1/3] END criterion=entropy, max_depth=30, min_samples_leaf=2, n_estimators=150;, score=0.981 total time=   2.9s
# [CV 2/3] END criterion=entropy, max_depth=30, min_samples_leaf=2, n_estimators=150;, score=0.984 total time=   2.9s
# [CV 3/3] END criterion=entropy, max_depth=30, min_samples_leaf=2, n_estimators=150;, score=0.983 total time=   2.8s
# [CV 1/3] END criterion=entropy, max_depth=30, min_samples_leaf=2, n_estimators=200;, score=0.981 total time=   3.8s
# [CV 2/3] END criterion=entropy, max_depth=30, min_samples_leaf=2, n_estimators=200;, score=0.983 total time=   3.9s
# [CV 3/3] END criterion=entropy, max_depth=30, min_samples_leaf=2, n_estimators=200;, score=0.983 total time=   3.7s
# [CV 1/3] END criterion=entropy, max_depth=30, min_samples_leaf=4, n_estimators=100;, score=0.980 total time=   1.9s
# [CV 2/3] END criterion=entropy, max_depth=30, min_samples_leaf=4, n_estimators=100;, score=0.982 total time=   1.8s
# [CV 3/3] END criterion=entropy, max_depth=30, min_samples_leaf=4, n_estimators=100;, score=0.982 total time=   1.8s
# [CV 1/3] END criterion=entropy, max_depth=30, min_samples_leaf=4, n_estimators=150;, score=0.980 total time=   2.8s
# [CV 2/3] END criterion=entropy, max_depth=30, min_samples_leaf=4, n_estimators=150;, score=0.983 total time=   2.7s
# [CV 3/3] END criterion=entropy, max_depth=30, min_samples_leaf=4, n_estimators=150;, score=0.982 total time=   2.7s
# [CV 1/3] END criterion=entropy, max_depth=30, min_samples_leaf=4, n_estimators=200;, score=0.981 total time=   3.7s
# [CV 2/3] END criterion=entropy, max_depth=30, min_samples_leaf=4, n_estimators=200;, score=0.983 total time=   3.8s
# [CV 3/3] END criterion=entropy, max_depth=30, min_samples_leaf=4, n_estimators=200;, score=0.982 total time=   3.7s
# [CV 1/3] END criterion=entropy, max_depth=30, min_samples_leaf=8, n_estimators=100;, score=0.978 total time=   1.8s
# [CV 2/3] END criterion=entropy, max_depth=30, min_samples_leaf=8, n_estimators=100;, score=0.978 total time=   1.8s
# [CV 3/3] END criterion=entropy, max_depth=30, min_samples_leaf=8, n_estimators=100;, score=0.981 total time=   1.8s
# [CV 1/3] END criterion=entropy, max_depth=30, min_samples_leaf=8, n_estimators=150;, score=0.979 total time=   2.7s
# [CV 2/3] END criterion=entropy, max_depth=30, min_samples_leaf=8, n_estimators=150;, score=0.979 total time=   2.7s
# [CV 3/3] END criterion=entropy, max_depth=30, min_samples_leaf=8, n_estimators=150;, score=0.982 total time=   2.7s
# [CV 1/3] END criterion=entropy, max_depth=30, min_samples_leaf=8, n_estimators=200;, score=0.978 total time=   3.6s
# [CV 2/3] END criterion=entropy, max_depth=30, min_samples_leaf=8, n_estimators=200;, score=0.979 total time=   3.6s
# [CV 3/3] END criterion=entropy, max_depth=30, min_samples_leaf=8, n_estimators=200;, score=0.980 total time=   3.6s
# [CV 1/3] END criterion=entropy, max_depth=50, min_samples_leaf=1, n_estimators=100;, score=0.982 total time=   1.8s
# [CV 2/3] END criterion=entropy, max_depth=50, min_samples_leaf=1, n_estimators=100;, score=0.984 total time=   2.0s
# [CV 3/3] END criterion=entropy, max_depth=50, min_samples_leaf=1, n_estimators=100;, score=0.982 total time=   1.8s
# [CV 1/3] END criterion=entropy, max_depth=50, min_samples_leaf=1, n_estimators=150;, score=0.981 total time=   2.7s
# [CV 2/3] END criterion=entropy, max_depth=50, min_samples_leaf=1, n_estimators=150;, score=0.984 total time=   2.9s
# [CV 3/3] END criterion=entropy, max_depth=50, min_samples_leaf=1, n_estimators=150;, score=0.982 total time=   3.0s
# [CV 1/3] END criterion=entropy, max_depth=50, min_samples_leaf=1, n_estimators=200;, score=0.982 total time=   3.7s
# [CV 2/3] END criterion=entropy, max_depth=50, min_samples_leaf=1, n_estimators=200;, score=0.984 total time=   4.0s
# [CV 3/3] END criterion=entropy, max_depth=50, min_samples_leaf=1, n_estimators=200;, score=0.983 total time=   3.9s
# [CV 1/3] END criterion=entropy, max_depth=50, min_samples_leaf=2, n_estimators=100;, score=0.980 total time=   1.9s
# [CV 2/3] END criterion=entropy, max_depth=50, min_samples_leaf=2, n_estimators=100;, score=0.983 total time=   1.9s
# [CV 3/3] END criterion=entropy, max_depth=50, min_samples_leaf=2, n_estimators=100;, score=0.982 total time=   1.9s
# [CV 1/3] END criterion=entropy, max_depth=50, min_samples_leaf=2, n_estimators=150;, score=0.981 total time=   2.9s
# [CV 2/3] END criterion=entropy, max_depth=50, min_samples_leaf=2, n_estimators=150;, score=0.984 total time=   2.9s
# [CV 3/3] END criterion=entropy, max_depth=50, min_samples_leaf=2, n_estimators=150;, score=0.983 total time=   2.9s
# [CV 1/3] END criterion=entropy, max_depth=50, min_samples_leaf=2, n_estimators=200;, score=0.981 total time=   3.9s
# [CV 2/3] END criterion=entropy, max_depth=50, min_samples_leaf=2, n_estimators=200;, score=0.983 total time=   3.7s
# [CV 3/3] END criterion=entropy, max_depth=50, min_samples_leaf=2, n_estimators=200;, score=0.983 total time=   3.7s
# [CV 1/3] END criterion=entropy, max_depth=50, min_samples_leaf=4, n_estimators=100;, score=0.980 total time=   1.8s
# [CV 2/3] END criterion=entropy, max_depth=50, min_samples_leaf=4, n_estimators=100;, score=0.982 total time=   1.8s
# [CV 3/3] END criterion=entropy, max_depth=50, min_samples_leaf=4, n_estimators=100;, score=0.982 total time=   1.8s
# [CV 1/3] END criterion=entropy, max_depth=50, min_samples_leaf=4, n_estimators=150;, score=0.980 total time=   2.8s
# [CV 2/3] END criterion=entropy, max_depth=50, min_samples_leaf=4, n_estimators=150;, score=0.983 total time=   2.9s
# [CV 3/3] END criterion=entropy, max_depth=50, min_samples_leaf=4, n_estimators=150;, score=0.982 total time=   2.7s
# [CV 1/3] END criterion=entropy, max_depth=50, min_samples_leaf=4, n_estimators=200;, score=0.981 total time=   3.9s
# [CV 2/3] END criterion=entropy, max_depth=50, min_samples_leaf=4, n_estimators=200;, score=0.983 total time=   3.8s
# [CV 3/3] END criterion=entropy, max_depth=50, min_samples_leaf=4, n_estimators=200;, score=0.982 total time=   3.7s
# [CV 1/3] END criterion=entropy, max_depth=50, min_samples_leaf=8, n_estimators=100;, score=0.978 total time=   1.8s
# [CV 2/3] END criterion=entropy, max_depth=50, min_samples_leaf=8, n_estimators=100;, score=0.978 total time=   1.8s
# [CV 3/3] END criterion=entropy, max_depth=50, min_samples_leaf=8, n_estimators=100;, score=0.981 total time=   1.7s
# [CV 1/3] END criterion=entropy, max_depth=50, min_samples_leaf=8, n_estimators=150;, score=0.979 total time=   2.7s
# [CV 2/3] END criterion=entropy, max_depth=50, min_samples_leaf=8, n_estimators=150;, score=0.979 total time=   2.8s
# [CV 3/3] END criterion=entropy, max_depth=50, min_samples_leaf=8, n_estimators=150;, score=0.982 total time=   2.7s
# [CV 1/3] END criterion=entropy, max_depth=50, min_samples_leaf=8, n_estimators=200;, score=0.978 total time=   3.5s
# [CV 2/3] END criterion=entropy, max_depth=50, min_samples_leaf=8, n_estimators=200;, score=0.979 total time=   3.7s
# [CV 3/3] END criterion=entropy, max_depth=50, min_samples_leaf=8, n_estimators=200;, score=0.980 total time=   3.7s
# {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 1, 'n_estimators': 200}
# 0.9829795555776034

# %%
grid.score(xtest,ytest)
# Out:
# 0.9823943661971831

# %%
ypred=grid.predict(xtest)

# %%
from sklearn.metrics import confusion_matrix, classification_report

plot_confusion_matrix(grid, xtest, ytest)
plt.xlabel('predicted phase')
plt.ylabel('''actual phase
              (BCC= 2, FCC+BCC= 1, FCC= 0)  ''')
# Out:
# Text(0, 0.5, 'actual phase\n              (BCC= 2, FCC+BCC= 1, FCC= 0)  ')

# %%
print(classification_report(ytest, ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98       717
#            1       0.96      0.98      0.97       710
#            2       0.99      0.99      0.99      1129
#
#     accuracy                           0.98      2556
#    macro avg       0.98      0.98      0.98      2556
# weighted avg       0.98      0.98      0.98      2556

# %%
from sklearn.inspection import permutation_importance


pi= permutation_importance(grid, xtrain, ytrain, random_state=42)
result=pi.importances_mean

fi = pd.DataFrame(result, index= xtrain.columns, columns= ['importance']).sort_values('importance', ascending=False)

print(fi)
# Out:
#        importance
# VEC      0.381708
# Ni       0.019270
# δ        0.016453
# Δsₘᵢₓ    0.005517
# Fe       0.004695
# Tm       0.004245
# ΔHₘᵢₓ    0.003619
# Δχ       0.003443
# Al       0.003326
# Ω        0.002758
# Co       0.001937
# Cr       0.001702
