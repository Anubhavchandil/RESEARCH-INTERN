# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics._plot.confusion_matrix import plot_confusion_matrix

df= pd.read_excel('output_params_Phase.xlsx')

# # FCC=0, FCC+BCC=1, BCC=2

data= df.drop('Phase',axis='columns')
target= df['Phase']

from sklearn.model_selection import train_test_split

xtrain,xtest,ytrain,ytest= train_test_split(data,target,test_size=0.2,random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
clf= DecisionTreeClassifier()

# %%
#DECISION TREE
from sklearn.model_selection import GridSearchCV
rf_params = { 'criterion' : ["gini", "entropy"],
             'splitter' : ["best", "random"],
             'max_depth': [None,1,5,10,20,30,40,50],
             'min_samples_split': [2,4,6,8,10],
             'min_samples_leaf': [1,2,3,5,6],
             'max_features' : ["auto", "log2",None]
}
clf = DecisionTreeClassifier(random_state=42)
grid = GridSearchCV(clf, rf_params, cv=3, scoring='accuracy',verbose=3)
grid.fit(xtrain, ytrain)
print(grid.best_params_)
print(grid.best_score_)
# Out:
# Fitting 3 folds for each of 2400 candidates, totalling 7200 fits
# [CV 1/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, splitter=best;, score=0.962 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, splitter=best;, score=0.968 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, splitter=best;, score=0.964 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, splitter=random;, score=0.957 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, splitter=random;, score=0.955 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, splitter=random;, score=0.958 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=4, splitter=best;, score=0.961 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=4, splitter=best;, score=0.967 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=4, splitter=best;, score=0.959 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=4, splitter=random;, score=0.949 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=4, splitter=random;, score=0.952 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=4, splitter=random;, score=0.964 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=6, splitter=best;, score=0.959 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=6, splitter=best;, score=0.962 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=6, splitter=best;, score=0.964 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=6, splitter=random;, score=0.953 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=6, splitter=random;, score=0.952 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=6, splitter=random;, score=0.955 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=8, splitter=best;, score=0.964 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=8, splitter=best;, score=0.962 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=8, splitter=best;, score=0.968 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=8, splitter=random;, score=0.957 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=8, splitter=random;, score=0.958 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=8, splitter=random;, score=0.955 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=10, splitter=best;, score=0.956 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=10, splitter=best;, score=0.963 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=10, splitter=best;, score=0.964 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=10, splitter=random;, score=0.941 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=10, splitter=random;, score=0.957 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=10, splitter=random;, score=0.950 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=2, splitter=best;, score=0.956 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=2, splitter=best;, score=0.964 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=2, splitter=best;, score=0.961 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=2, splitter=random;, score=0.947 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=2, splitter=random;, score=0.953 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=2, splitter=random;, score=0.950 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=4, splitter=best;, score=0.956 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=4, splitter=best;, score=0.964 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=4, splitter=best;, score=0.961 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=4, splitter=random;, score=0.947 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=4, splitter=random;, score=0.953 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=4, splitter=random;, score=0.950 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=6, splitter=best;, score=0.960 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=6, splitter=best;, score=0.959 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=6, splitter=best;, score=0.966 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=6, splitter=random;, score=0.943 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=6, splitter=random;, score=0.953 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=6, splitter=random;, score=0.955 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=8, splitter=best;, score=0.963 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=8, splitter=best;, score=0.960 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=8, splitter=best;, score=0.966 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=8, splitter=random;, score=0.950 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=8, splitter=random;, score=0.941 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=8, splitter=random;, score=0.955 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=10, splitter=best;, score=0.965 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=10, splitter=best;, score=0.959 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=10, splitter=best;, score=0.958 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=10, splitter=random;, score=0.956 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=10, splitter=random;, score=0.952 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=10, splitter=random;, score=0.940 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=3, min_samples_split=2, splitter=best;, score=0.959 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=3, min_samples_split=2, splitter=best;, score=0.961 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=3, min_samples_split=2, splitter=best;, score=0.962 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=3, min_samples_split=2, splitter=random;, score=0.944 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=3, min_samples_split=2, splitter=random;, score=0.946 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=3, min_samples_split=2, splitter=random;, score=0.959 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=3, min_samples_split=4, splitter=best;, score=0.959 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=3, min_samples_split=4, splitter=best;, score=0.961 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=3, min_samples_split=4, splitter=best;, score=0.962 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=3, min_samples_split=4, splitter=random;, score=0.944 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=3, min_samples_split=4, splitter=random;, score=0.946 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=3, min_samples_split=4, splitter=random;, score=0.959 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=3, min_samples_split=6, splitter=best;, score=0.959 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=3, min_samples_split=6, splitter=best;, score=0.961 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=3, min_samples_split=6, splitter=best;, score=0.962 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=3, min_samples_split=6, splitter=random;, score=0.944 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=3, min_samples_split=6, splitter=random;, score=0.946 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=3, min_samples_split=6, splitter=random;, score=0.959 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=3, min_samples_split=8, splitter=best;, score=0.959 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=3, min_samples_split=8, splitter=best;, score=0.964 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=3, min_samples_split=8, splitter=best;, score=0.959 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=3, min_samples_split=8, splitter=random;, score=0.947 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=3, min_samples_split=8, splitter=random;, score=0.952 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=3, min_samples_split=8, splitter=random;, score=0.949 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=3, min_samples_split=10, splitter=best;, score=0.955 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=3, min_samples_split=10, splitter=best;, score=0.966 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=3, min_samples_split=10, splitter=best;, score=0.967 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=3, min_samples_split=10, splitter=random;, score=0.945 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=3, min_samples_split=10, splitter=random;, score=0.947 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=3, min_samples_split=10, splitter=random;, score=0.949 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=5, min_samples_split=2, splitter=best;, score=0.962 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=5, min_samples_split=2, splitter=best;, score=0.963 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=5, min_samples_split=2, splitter=best;, score=0.958 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=5, min_samples_split=2, splitter=random;, score=0.942 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=5, min_samples_split=2, splitter=random;, score=0.943 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=5, min_samples_split=2, splitter=random;, score=0.951 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=5, min_samples_split=4, splitter=best;, score=0.962 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=5, min_samples_split=4, splitter=best;, score=0.963 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=5, min_samples_split=4, splitter=best;, score=0.958 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=5, min_samples_split=4, splitter=random;, score=0.942 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=5, min_samples_split=4, splitter=random;, score=0.943 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=5, min_samples_split=4, splitter=random;, score=0.951 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=5, min_samples_split=6, splitter=best;, score=0.962 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=5, min_samples_split=6, splitter=best;, score=0.963 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=5, min_samples_split=6, splitter=best;, score=0.958 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=5, min_samples_split=6, splitter=random;, score=0.942 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=5, min_samples_split=6, splitter=random;, score=0.943 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=5, min_samples_split=6, splitter=random;, score=0.951 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=5, min_samples_split=8, splitter=best;, score=0.962 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=5, min_samples_split=8, splitter=best;, score=0.963 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=5, min_samples_split=8, splitter=best;, score=0.958 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=5, min_samples_split=8, splitter=random;, score=0.942 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=5, min_samples_split=8, splitter=random;, score=0.943 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=5, min_samples_split=8, splitter=random;, score=0.951 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=5, min_samples_split=10, splitter=best;, score=0.962 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=5, min_samples_split=10, splitter=best;, score=0.963 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=5, min_samples_split=10, splitter=best;, score=0.958 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=5, min_samples_split=10, splitter=random;, score=0.942 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=5, min_samples_split=10, splitter=random;, score=0.943 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=5, min_samples_split=10, splitter=random;, score=0.951 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=6, min_samples_split=2, splitter=best;, score=0.952 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=6, min_samples_split=2, splitter=best;, score=0.963 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=6, min_samples_split=2, splitter=best;, score=0.961 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=6, min_samples_split=2, splitter=random;, score=0.945 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=6, min_samples_split=2, splitter=random;, score=0.948 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=6, min_samples_split=2, splitter=random;, score=0.945 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=6, min_samples_split=4, splitter=best;, score=0.952 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=6, min_samples_split=4, splitter=best;, score=0.963 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=6, min_samples_split=4, splitter=best;, score=0.961 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=6, min_samples_split=4, splitter=random;, score=0.945 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=6, min_samples_split=4, splitter=random;, score=0.948 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=6, min_samples_split=4, splitter=random;, score=0.945 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=6, min_samples_split=6, splitter=best;, score=0.952 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=6, min_samples_split=6, splitter=best;, score=0.963 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=6, min_samples_split=6, splitter=best;, score=0.961 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=6, min_samples_split=6, splitter=random;, score=0.945 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=6, min_samples_split=6, splitter=random;, score=0.948 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=6, min_samples_split=6, splitter=random;, score=0.945 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=6, min_samples_split=8, splitter=best;, score=0.952 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=6, min_samples_split=8, splitter=best;, score=0.963 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=6, min_samples_split=8, splitter=best;, score=0.961 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=6, min_samples_split=8, splitter=random;, score=0.945 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=6, min_samples_split=8, splitter=random;, score=0.948 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=6, min_samples_split=8, splitter=random;, score=0.945 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=6, min_samples_split=10, splitter=best;, score=0.952 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=6, min_samples_split=10, splitter=best;, score=0.963 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=6, min_samples_split=10, splitter=best;, score=0.961 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=6, min_samples_split=10, splitter=random;, score=0.945 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=6, min_samples_split=10, splitter=random;, score=0.948 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=6, min_samples_split=10, splitter=random;, score=0.945 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, splitter=best;, score=0.962 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, splitter=best;, score=0.968 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, splitter=best;, score=0.964 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, splitter=random;, score=0.957 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, splitter=random;, score=0.955 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, splitter=random;, score=0.958 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=4, splitter=best;, score=0.961 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=4, splitter=best;, score=0.967 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=4, splitter=best;, score=0.959 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=4, splitter=random;, score=0.949 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=4, splitter=random;, score=0.952 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=4, splitter=random;, score=0.964 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=6, splitter=best;, score=0.959 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=6, splitter=best;, score=0.962 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=6, splitter=best;, score=0.964 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=6, splitter=random;, score=0.953 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=6, splitter=random;, score=0.952 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=6, splitter=random;, score=0.955 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=8, splitter=best;, score=0.964 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=8, splitter=best;, score=0.962 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=8, splitter=best;, score=0.968 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=8, splitter=random;, score=0.957 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=8, splitter=random;, score=0.958 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=8, splitter=random;, score=0.955 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, splitter=best;, score=0.956 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, splitter=best;, score=0.963 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, splitter=best;, score=0.964 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, splitter=random;, score=0.941 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, splitter=random;, score=0.957 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, splitter=random;, score=0.950 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, splitter=best;, score=0.956 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, splitter=best;, score=0.964 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, splitter=best;, score=0.961 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, splitter=random;, score=0.947 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, splitter=random;, score=0.953 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, splitter=random;, score=0.950 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=4, splitter=best;, score=0.956 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=4, splitter=best;, score=0.964 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=4, splitter=best;, score=0.961 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=4, splitter=random;, score=0.947 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=4, splitter=random;, score=0.953 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=4, splitter=random;, score=0.950 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=6, splitter=best;, score=0.960 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=6, splitter=best;, score=0.959 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=6, splitter=best;, score=0.966 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=6, splitter=random;, score=0.943 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=6, splitter=random;, score=0.953 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=6, splitter=random;, score=0.955 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=8, splitter=best;, score=0.963 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=8, splitter=best;, score=0.960 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=8, splitter=best;, score=0.966 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=8, splitter=random;, score=0.950 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=8, splitter=random;, score=0.941 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=8, splitter=random;, score=0.955 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=10, splitter=best;, score=0.965 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=10, splitter=best;, score=0.959 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=10, splitter=best;, score=0.958 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=10, splitter=random;, score=0.956 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=10, splitter=random;, score=0.952 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=10, splitter=random;, score=0.940 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=3, min_samples_split=2, splitter=best;, score=0.959 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=3, min_samples_split=2, splitter=best;, score=0.961 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=3, min_samples_split=2, splitter=best;, score=0.962 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=3, min_samples_split=2, splitter=random;, score=0.944 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=3, min_samples_split=2, splitter=random;, score=0.946 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=3, min_samples_split=2, splitter=random;, score=0.959 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=3, min_samples_split=4, splitter=best;, score=0.959 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=3, min_samples_split=4, splitter=best;, score=0.961 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=3, min_samples_split=4, splitter=best;, score=0.962 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=3, min_samples_split=4, splitter=random;, score=0.944 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=3, min_samples_split=4, splitter=random;, score=0.946 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=3, min_samples_split=4, splitter=random;, score=0.959 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=3, min_samples_split=6, splitter=best;, score=0.959 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=3, min_samples_split=6, splitter=best;, score=0.961 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=3, min_samples_split=6, splitter=best;, score=0.962 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=3, min_samples_split=6, splitter=random;, score=0.944 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=3, min_samples_split=6, splitter=random;, score=0.946 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=3, min_samples_split=6, splitter=random;, score=0.959 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=3, min_samples_split=8, splitter=best;, score=0.959 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=3, min_samples_split=8, splitter=best;, score=0.964 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=3, min_samples_split=8, splitter=best;, score=0.959 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=3, min_samples_split=8, splitter=random;, score=0.947 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=3, min_samples_split=8, splitter=random;, score=0.952 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=3, min_samples_split=8, splitter=random;, score=0.949 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=3, min_samples_split=10, splitter=best;, score=0.955 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=3, min_samples_split=10, splitter=best;, score=0.966 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=3, min_samples_split=10, splitter=best;, score=0.967 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=3, min_samples_split=10, splitter=random;, score=0.945 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=3, min_samples_split=10, splitter=random;, score=0.947 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=3, min_samples_split=10, splitter=random;, score=0.949 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=2, splitter=best;, score=0.962 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=2, splitter=best;, score=0.963 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=2, splitter=best;, score=0.958 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=2, splitter=random;, score=0.942 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=2, splitter=random;, score=0.943 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=2, splitter=random;, score=0.951 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=4, splitter=best;, score=0.962 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=4, splitter=best;, score=0.963 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=4, splitter=best;, score=0.958 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=4, splitter=random;, score=0.942 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=4, splitter=random;, score=0.943 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=4, splitter=random;, score=0.951 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=6, splitter=best;, score=0.962 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=6, splitter=best;, score=0.963 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=6, splitter=best;, score=0.958 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=6, splitter=random;, score=0.942 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=6, splitter=random;, score=0.943 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=6, splitter=random;, score=0.951 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=8, splitter=best;, score=0.962 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=8, splitter=best;, score=0.963 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=8, splitter=best;, score=0.958 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=8, splitter=random;, score=0.942 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=8, splitter=random;, score=0.943 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=8, splitter=random;, score=0.951 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=10, splitter=best;, score=0.962 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=10, splitter=best;, score=0.963 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=10, splitter=best;, score=0.958 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=10, splitter=random;, score=0.942 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=10, splitter=random;, score=0.943 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=10, splitter=random;, score=0.951 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=6, min_samples_split=2, splitter=best;, score=0.952 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=6, min_samples_split=2, splitter=best;, score=0.963 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=6, min_samples_split=2, splitter=best;, score=0.961 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=6, min_samples_split=2, splitter=random;, score=0.945 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=6, min_samples_split=2, splitter=random;, score=0.948 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=6, min_samples_split=2, splitter=random;, score=0.945 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=6, min_samples_split=4, splitter=best;, score=0.952 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=6, min_samples_split=4, splitter=best;, score=0.963 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=6, min_samples_split=4, splitter=best;, score=0.961 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=6, min_samples_split=4, splitter=random;, score=0.945 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=6, min_samples_split=4, splitter=random;, score=0.948 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=6, min_samples_split=4, splitter=random;, score=0.945 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=6, min_samples_split=6, splitter=best;, score=0.952 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=6, min_samples_split=6, splitter=best;, score=0.963 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=6, min_samples_split=6, splitter=best;, score=0.961 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=6, min_samples_split=6, splitter=random;, score=0.945 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=6, min_samples_split=6, splitter=random;, score=0.948 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=6, min_samples_split=6, splitter=random;, score=0.945 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=6, min_samples_split=8, splitter=best;, score=0.952 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=6, min_samples_split=8, splitter=best;, score=0.963 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=6, min_samples_split=8, splitter=best;, score=0.961 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=6, min_samples_split=8, splitter=random;, score=0.945 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=6, min_samples_split=8, splitter=random;, score=0.948 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=6, min_samples_split=8, splitter=random;, score=0.945 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=6, min_samples_split=10, splitter=best;, score=0.952 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=6, min_samples_split=10, splitter=best;, score=0.963 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=6, min_samples_split=10, splitter=best;, score=0.961 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=6, min_samples_split=10, splitter=random;, score=0.945 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=6, min_samples_split=10, splitter=random;, score=0.948 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=6, min_samples_split=10, splitter=random;, score=0.945 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=2, splitter=best;, score=0.964 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=2, splitter=best;, score=0.969 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=2, splitter=best;, score=0.968 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=2, splitter=random;, score=0.961 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=2, splitter=random;, score=0.969 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=2, splitter=random;, score=0.967 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=4, splitter=best;, score=0.964 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=4, splitter=best;, score=0.967 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=4, splitter=best;, score=0.963 total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=4, splitter=random;, score=0.960 total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=4, splitter=random;, score=0.969 total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=4, splitter=random;, score=0.967 total time=   0.0s
# ...
# [CV 1/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=2, min_samples_split=8, splitter=best;, score=0.963 total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=2, min_samples_split=8, splitter=best;, score=0.967 total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=2, min_samples_split=8, splitter=best;, score=0.973 total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=2, min_samples_split=8, splitter=random;, score=0.962 total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=2, min_samples_split=8, splitter=random;, score=0.967 total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=2, min_samples_split=8, splitter=random;, score=0.969 total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=2, min_samples_split=10, splitter=best;, score=0.965 total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=2, min_samples_split=10, splitter=best;, score=0.966 total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=2, min_samples_split=10, splitter=best;, score=0.971 total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=2, min_samples_split=10, splitter=random;, score=0.967 total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=2, min_samples_split=10, splitter=random;, score=0.965 total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=2, min_samples_split=10, splitter=random;, score=0.974 total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=3, min_samples_split=2, splitter=best;, score=0.961 total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=3, min_samples_split=2, splitter=best;, score=0.969 total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=3, min_samples_split=2, splitter=best;, score=0.967 total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=3, min_samples_split=2, splitter=random;, score=0.969 total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=3, min_samples_split=2, splitter=random;, score=0.964 total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=3, min_samples_split=2, splitter=random;, score=0.970 total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=3, min_samples_split=4, splitter=best;, score=0.961 total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=3, min_samples_split=4, splitter=best;, score=0.969 total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=3, min_samples_split=4, splitter=best;, score=0.967 total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=3, min_samples_split=4, splitter=random;, score=0.969 total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=3, min_samples_split=4, splitter=random;, score=0.964 total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=3, min_samples_split=4, splitter=random;, score=0.970 total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=3, min_samples_split=6, splitter=best;, score=0.961 total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=3, min_samples_split=6, splitter=best;, score=0.969 total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=3, min_samples_split=6, splitter=best;, score=0.967 total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=3, min_samples_split=6, splitter=random;, score=0.969 total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=3, min_samples_split=6, splitter=random;, score=0.964 total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=3, min_samples_split=6, splitter=random;, score=0.970 total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=3, min_samples_split=8, splitter=best;, score=0.963 total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=3, min_samples_split=8, splitter=best;, score=0.967 total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=3, min_samples_split=8, splitter=best;, score=0.968 total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=3, min_samples_split=8, splitter=random;, score=0.970 total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=3, min_samples_split=8, splitter=random;, score=0.961 total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=3, min_samples_split=8, splitter=random;, score=0.972 total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=3, min_samples_split=10, splitter=best;, score=0.965 total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=3, min_samples_split=10, splitter=best;, score=0.967 total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=3, min_samples_split=10, splitter=best;, score=0.970 total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=3, min_samples_split=10, splitter=random;, score=0.970 total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=3, min_samples_split=10, splitter=random;, score=0.967 total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=3, min_samples_split=10, splitter=random;, score=0.972 total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=5, min_samples_split=2, splitter=best;, score=0.969 total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=5, min_samples_split=2, splitter=best;, score=0.967 total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=5, min_samples_split=2, splitter=best;, score=0.972 total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=5, min_samples_split=2, splitter=random;, score=0.970 total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=5, min_samples_split=2, splitter=random;, score=0.972 total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=5, min_samples_split=2, splitter=random;, score=0.967 total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=5, min_samples_split=4, splitter=best;, score=0.969 total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=5, min_samples_split=4, splitter=best;, score=0.967 total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=5, min_samples_split=4, splitter=best;, score=0.972 total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=5, min_samples_split=4, splitter=random;, score=0.970 total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=5, min_samples_split=4, splitter=random;, score=0.972 total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=5, min_samples_split=4, splitter=random;, score=0.967 total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=5, min_samples_split=6, splitter=best;, score=0.969 total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=5, min_samples_split=6, splitter=best;, score=0.967 total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=5, min_samples_split=6, splitter=best;, score=0.972 total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=5, min_samples_split=6, splitter=random;, score=0.970 total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=5, min_samples_split=6, splitter=random;, score=0.972 total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=5, min_samples_split=6, splitter=random;, score=0.967 total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=5, min_samples_split=8, splitter=best;, score=0.969 total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=5, min_samples_split=8, splitter=best;, score=0.967 total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=5, min_samples_split=8, splitter=best;, score=0.972 total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=5, min_samples_split=8, splitter=random;, score=0.970 total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=5, min_samples_split=8, splitter=random;, score=0.972 total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=5, min_samples_split=8, splitter=random;, score=0.967 total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=5, min_samples_split=10, splitter=best;, score=0.969 total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=5, min_samples_split=10, splitter=best;, score=0.967 total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=5, min_samples_split=10, splitter=best;, score=0.972 total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=5, min_samples_split=10, splitter=random;, score=0.970 total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=5, min_samples_split=10, splitter=random;, score=0.972 total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=5, min_samples_split=10, splitter=random;, score=0.967 total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=6, min_samples_split=2, splitter=best;, score=0.968 total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=6, min_samples_split=2, splitter=best;, score=0.968 total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=6, min_samples_split=2, splitter=best;, score=0.972 total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=6, min_samples_split=2, splitter=random;, score=0.970 total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=6, min_samples_split=2, splitter=random;, score=0.972 total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=6, min_samples_split=2, splitter=random;, score=0.967 total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=6, min_samples_split=4, splitter=best;, score=0.968 total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=6, min_samples_split=4, splitter=best;, score=0.968 total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=6, min_samples_split=4, splitter=best;, score=0.972 total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=6, min_samples_split=4, splitter=random;, score=0.970 total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=6, min_samples_split=4, splitter=random;, score=0.972 total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=6, min_samples_split=4, splitter=random;, score=0.967 total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=6, min_samples_split=6, splitter=best;, score=0.968 total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=6, min_samples_split=6, splitter=best;, score=0.968 total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=6, min_samples_split=6, splitter=best;, score=0.972 total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=6, min_samples_split=6, splitter=random;, score=0.970 total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=6, min_samples_split=6, splitter=random;, score=0.972 total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=6, min_samples_split=6, splitter=random;, score=0.967 total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=6, min_samples_split=8, splitter=best;, score=0.968 total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=6, min_samples_split=8, splitter=best;, score=0.968 total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=6, min_samples_split=8, splitter=best;, score=0.972 total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=6, min_samples_split=8, splitter=random;, score=0.970 total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=6, min_samples_split=8, splitter=random;, score=0.972 total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=6, min_samples_split=8, splitter=random;, score=0.967 total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=6, min_samples_split=10, splitter=best;, score=0.968 total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=6, min_samples_split=10, splitter=best;, score=0.968 total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=6, min_samples_split=10, splitter=best;, score=0.972 total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=6, min_samples_split=10, splitter=random;, score=0.970 total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=6, min_samples_split=10, splitter=random;, score=0.972 total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=50, max_features=None, min_samples_leaf=6, min_samples_split=10, splitter=random;, score=0.967 total time=   0.0s
# {'criterion': 'gini', 'max_depth': 10, 'max_features': None, 'min_samples_leaf': 5, 'min_samples_split': 2, 'splitter': 'best'}
# 0.9717302773035171

# %%
grid.score(xtest, ytest)
# Out:
# 0.9769170579029735

# %%
ypred= grid.predict(xtest)

# %%
from sklearn.metrics import confusion_matrix, classification_report

plot_confusion_matrix(grid, xtest, ytest)
plt.xlabel('predicted phase')
plt.ylabel('''actual phase
              (BCC= 2, FCC+BCC= 1, FCC= 0)  ''')
# Out:
# Text(0, 0.5, 'actual phase\n              (BCC= 2, FCC+BCC= 1, FCC= 0)  ')

# %%
print(classification_report(ytest, ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97       717
#            1       0.95      0.96      0.96       710
#            2       0.99      0.99      0.99      1129
#
#     accuracy                           0.98      2556
#    macro avg       0.97      0.97      0.97      2556
# weighted avg       0.98      0.98      0.98      2556

# %%
from sklearn.inspection import permutation_importance


pi= permutation_importance(grid, xtrain, ytrain, random_state=42)
result=pi.importances_mean

fi = pd.DataFrame(result, index= xtrain.columns, columns= ['importance']).sort_values('importance', ascending=False)

print(fi)
# Out:
#        importance
# VEC      0.538453
# Al       0.156901
# δ        0.042668
# Fe       0.033474
# Ni       0.022185
# Tm       0.005047
# Co       0.004265
# Δsₘᵢₓ    0.004069
# Δχ       0.001624
# Ω        0.001604
# ΔHₘᵢₓ    0.001428
# Cr       0.000254
